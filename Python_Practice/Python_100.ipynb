# %%
#1 Hello world Program
print("Hello, World")
# Out:
# Hello, World

# %%
# 2. Simple calculator:

a = int(input("Enter the first number : "))
b = int(input("Enter the Second number : "))
print("Sum : ", a + b)
print("Difference : ", a - b)
print("Product : ", a * b)
print("Quotient : ", a / b)
# Out:
# Sum :  12
# Difference :  8
# Product :  20
# Quotient :  5.0

# %%
# 3. create Simple calculator in Python

# To make this work , we use input () to get data from the user and if statement 
# to decide which math operation to perform.

# 1 Get the first number 
num1 = float(input("Enter first number :  "))

# 2. Get the operator the ( the aromatic sign)
op = input("Enter operator ( +,-,*,/) : ")

# 3. Get the scond number 
num2 = float(input("Enter second number : "))

# Logic to calculate the result 
if op == "+":
    print("Total : ", num1+num2)
elif op == "-" :
    print("Total : ", num1-num2)
elif op == "*" :
    print("Total ", num1 * num2)
elif op == "/" :
    if num2 !=0 :
        print("Total :", num1/num2)
    else:
        print("Error : Cannot divide by zero ! ")
else:
    print(" Invalid operator !")
# Out:
# Total : 25.0

# %%
# A Professional Touch : match -case :
# if you using python 3.10 or newer , you can use cleaner sysntax call match-case. It's perfect for calculatior:


num1 = float(input("Enter your first number : "))
op = input("Enter operator (+, -, *, /)")
num2 = float((input("Enter your second number :")))
match op:
    case "+":
        result = num1 + num2
    case "-":
        result = num1 - num2
    case "*" :
        result = num1 * num2
    case "/":
        result = num1/num2 if num2 != o else "Error"
    case _ :
        result = "Invalid"
    
print(f"Result : {result}")
# Out:
# Result : 20.0

# %%
# 3 Factorial of a number 
# A factorial is just a multiplication countdown. You take a number and multiply it by every whole number below it until you hit 1.

def factorial(n):
    if n == 0:
        return 1
    else:
        return n*factorial(n-1)
    
number = int(input("Enter your number : "))
print("Factorial : ",factorial(number))
# Out:
# Factorial :  120

# %%
# write a program to enter a number from user and check if it is greater than or smaller

a = int(input("Enter you number : "))

if a > 10 :
    print("It is greater ",a)
elif a == 10:
    print("It is equal ")
else:
    print("It is smaller ")
# Out:
# It is equal

# %%
# Write a program to enter 3 number from user and print the greater number ?

num1 =  int(input('Enter your num1 : '))
num2 = int(input("Enter your num2 : "))
num3 = int(input("Enter your num3 : "))

if num1 >num2 and num1 >num3:
    print("Number 1 is greater ")
elif num2 >num1 and num2 >num3:
    print("Number 2 is greater")
else:
    print("Number 3 is greater")
# Out:
# Number 3 is greater

# %%
# Write a program to enter 3 number from user and print the greater number?

a =  int(input('Enter your num1 : '))
b = int(input("Enter your num2 : "))
c = int(input("Enter your num3 : "))

if a >=b :
    if a > c:
        print("Greater a = ",a)
    else:
        print("Greater c = ",c)
else:
    if b >=c:
        print("Greater b= ",b)
    else:
        print("Greater c =",c)
    print("============end============")
# Out:
# Greater b=  30
# ============end============

# %%
# write a program to enter a number between 0 to 9 and print its character format.

a = int(input("Enter your number :  "))

match a:
    case 1:
        print("one")
    case 2 :
        print("two")
    case 3:
        print("Three")
    case 4:
        print("Four")
    case 5 :
        print("Five")
    case 6:
        print("Six")
    case 7:
        print("Seven")
    case 8:
        print("Eight")
    case 9:
        print("Nine")
    case _:
        print("incorrect")
# Out:
# Eight

# %%
#Write a program to enter a character from user and check it is vowel and consonent.

a = input("Enter your charcter :  ")

if a == "a":
    print("Vowel")
elif a== "e":
    print('vowel')
elif a == "i":
    print('vowel')
elif a == 'o':
    print('vowel')
else:
    print("Consonent -")
# Out:
# vowel

# %%
a = input("Enter your charcter :  ")

if a == 'a' or a=='e' or a== 'i' or a=='u':
    print('vowel')
else:
    print('consonent')
# Out:
# vowel

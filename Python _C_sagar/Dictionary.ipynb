# %%
# Check if a given key exists in a dictionary or not:

d ={ 1 :"jubayer", 
     2 : "Jihan",
     3 : "Sayema",
     4 : "johura"   }

User_input =int(input("Enter your input : "))

if User_input in d.keys():
    print('Key is present in the dictionary ')
    print('Value is', ':',d[User_input])
else:
    print("key does not exit in the dictionary ")
# Out:
# Key is present in the dictionary
# Value is : Jihan

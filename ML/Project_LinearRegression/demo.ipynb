# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import warnings
warnings.filterwarnings("ignore")
pd.pandas.set_option("display.max_columns", None)

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PowerTransformer, LabelEncoder, OrdinalEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# range(len(list(models))): Iterates through the dictionary using index numbers (0, 1, ...). (Note: This is clunky in Python; see the tip below).
#
# model.fit(...): Trains the machine learning model on the training features (X_train) and target values (y_train).

# %%
# 1. Define models to train and empty lists to track results
models = {
    "Linear Regression": LinearRegression()
}

model_list = []
r2_score_list = []

# 2. Iterate through each model in the dictionary
for i in range(len(list(models))):
    # Extract the model instance
    model = list(models.values())[i]
    
    # Train the model on training data
    model.fit(X_train, y_train)

    # Make predictions on both train and test sets
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Calculate metrics (MAE, RMSE, R2) using a custom evaluation function
    model_train_mae, model_train_rmse, model_train_r2 = evaluate_reg(y_train, y_train_pred)
    model_test_mae, model_test_rmse, model_test_r2 = evaluate_reg(y_test, y_test_pred)

    # Store the model's name
    model_name = list(models.keys())[i]
    print(model_name)
    model_list.append(model_name)

    # Display training metrics formatted to 4 decimal places
    print('Model performance for Training set')
    print("- RMSE: {:.4f}".format(model_train_rmse))
    print("- MAE: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')

    # Display testing metrics
    print('Model performance for Test set')
    print("- RMSE: {:.4f}".format(model_test_rmse))
    print("- MAE: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    
    # Save the test R2 score for final comparison
    r2_score_list.append(model_test_r2)

    # Print decorative separators for readability
    print('='*35)
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 15
#      12 model = list(models.values())[i]
#      14 # Train the model on training data
# ---> 15 model.fit(X_train, y_train)
#      17 # Make predictions on both train and test sets
#      18 y_train_pred = model.predict(X_train)
#
# NameError: name 'X_train' is not defined

# %%
sent1 = 'i am jubayer'

sent1.split()
# Out:
# ['i', 'am', 'jubayer']

# %%
sent2 = 'hello',
            'my name is jubayer' '
# Out:
#   Cell In[11], line 2
#     'my name is jubayer' '
#     ^
# IndentationError: unexpected indent

# %%
dic = { 1: 'jubyer',
        2:'Hussain',
        3: "jihan"

}

# %%
for i in range(len(dic)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in dic.items():
    print(i)
# Out:
# (1, 'jubyer')
# (2, 'Hussain')
# (3, 'jihan')

# %%
for i in dic.values():
    print(i)
# Out:
# jubyer
# Hussain
# jihan

# %%
for i in dic.keys():
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in dic.values():

    if i =
    print(i)

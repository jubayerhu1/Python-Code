# %%
import pandas as pd
import numpy as np
#from sklearn import train_test_split
import matplotlib.pyplot as plt

# %%
# 
df = pd.read_csv('/Volumes/study/A_data-science/Python-Code/ML/SimpleLinearRegression/.placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
plt.scatter(df['cgpa'],df['package'])

#plt.plot(df['cgpa'],df['package'])

plt.xlabel('CGPA')
plt.ylabel('Package')

plt.show()

# %%
x =df.iloc[: ,0:1]
y =df.iloc[: , -1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y, test_size=0.2, random_state=2)

# %%
x_train.head()
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77

# %%
y_train.head()
# Out:
# 137    3.13
# 163    3.91
# 111    2.25
# 123    2.30
# 109    4.06
# Name: package, dtype: float64

# %%
x_test.shape
# Out:
# (40, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
y_test.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %%
lr.predict(x_test.iloc[1].values.reshape(1,1)) # first row from main data
# Out:
# /opt/anaconda3/envs/jub/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.09324469])

# %%
plt.scatter(df['cgpa'],df['package'])

plt.plot(x_train,lr.predict(x_train), color ='red')

plt.xlabel('cgp')
plt.ylabel('Package')
plt.show()

# %%
m = lr.coef_
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_
b
# Out:
# np.float64(-0.8961119222429144)

# %%
x =8.58  #cgp

# %%
# y =mx+b
y = m*x+b

y
# Out:
# array([3.89111601])

# %%
# Practice ================

# %%
df = pd.read_csv('.placement.csv')
df.head(2)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98

# %%
df.shape
# Out:
# (200, 2)

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.title('package, cdgp')

plt.show()

# %%
x = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2, random_state=2)

# %%
x_train.head()
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77

# %%
y_train.head()
# Out:
# 137    3.13
# 163    3.91
# 111    2.25
# 123    2.30
# 109    4.06
# Name: package, dtype: float64

# %%
x_test.shape
# Out:
# (40, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
y_test.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %%
lr.predict(x_test.iloc[4].values.reshape(1,1))
# Out:
# /opt/anaconda3/envs/jub/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.6537286])

# %%
lr.predict(x_test.iloc[2].values.reshape(1,1))
# Out:
# /opt/anaconda3/envs/jub/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.38464568])

# %%
plt.scatter(df['cgpa'],df['package'])

plt.plot(x_train,lr.predict(x_train), color = 'red')

plt.xlabel('cgp')
plt.ylabel('package')

plt.show()

# %%
m = lr.coef_ # slop

# %%
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_ # intercept

# %%
b
# Out:
# np.float64(-0.8961119222429144)

# %%
x = 8.58 #cgp

# %%
y = m*x + b

# %%
y
# Out:
# array([3.89111601])

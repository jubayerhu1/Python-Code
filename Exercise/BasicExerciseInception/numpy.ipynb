# %%
print("hello")
# Out:
# hello

# %%
import numpy as np

# %%
# list 
l =[1,2,3,4]
print(l)
# Out:
# [1, 2, 3, 4]

# %%
# convert list to array
arra=np.array(l)
print(arra)
print(type(arra))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
# Type define of array 
a = np.array([1,2,3,4,5], dtype = float) #a = np.array([1,2,3,4,5], dtype = int)
print(a)
# Out:
# [1. 2. 3. 4. 5.]

# %%
# Dimention check 
d = a.ndim
print("This is one dimentiona array :", d)
# Out:
# This is one dimentiona array : 1

# %%
c = np.array([[1,2,3],[2,3,4]])
d =c.ndim
print("This is two dimentional array :",d)
# Out:
# This is two dimentional array : 2

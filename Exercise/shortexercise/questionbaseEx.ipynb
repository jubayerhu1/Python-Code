# %%
print ("program start ...")
# Out:
# program start ...

# %%
q What is th eout outpu 
a . low b. ok c.Error d. None

# %%
def balance(b):
    if b < 100 :
        return "LOW"
    return "ok"

print(balance(99))
# Out:
# LOW

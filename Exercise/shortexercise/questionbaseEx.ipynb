# %%
print ("program start ...")
# Out:
# program start ...

# %%
q What is th eout outpu 
a . low b. ok c.Error d. None

# %%
def balance(b):
    if b < 100 :
        return "LOW"
    return "ok"

print(balance(99))
# Out:
# LOW

# %% [markdown]
# what is the output A. student discount B. No discount c.16 d.Error

# %%
age =16
student = True
if age < 18:
    if student :
        print("Student discount ")
    else:
        print("No discount")
# Out:
# Student discount

# %%
16< 18
# Out:
# True

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import statistics as st
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Volumes/study/A_data-science/Python-Code/EDA -Assignment/.env/train.csv')

# %%
df[['OverallQual', 'GarageCars','GrLivArea']]
# Out:
#       OverallQual  GarageCars  GrLivArea
# 0               7           2       1710
# 1               6           2       1262
# 2               7           2       1786
# 3               7           3       1717
# 4               8           3       2198
# ...           ...         ...        ...
# 1455            6           2       1647
# 1456            6           2       2073
# 1457            7           1       2340
# 1458            5           1       1078
# 1459            5           1       1256
#
# [1460 rows x 3 columns]

# %%
df.corr(numeric_only= True)[['OverallQual', 'GarageCars','GrLivArea']]
# Out:
#                OverallQual  GarageCars  GrLivArea
# Id               -0.028365    0.016570   0.008273
# MSSubClass        0.032628   -0.040110   0.074853
# LotFrontage       0.251646    0.285691   0.402797
# LotArea           0.105806    0.154871   0.263116
# OverallQual       1.000000    0.600671   0.593007
# OverallCond      -0.091932   -0.185758  -0.079686
# YearBuilt         0.572323    0.537850   0.199010
# YearRemodAdd      0.550684    0.420622   0.287389
# MasVnrArea        0.411876    0.364204   0.390857
# BsmtFinSF1        0.239666    0.224054   0.208171
# BsmtFinSF2       -0.059119   -0.038264  -0.009640
# BsmtUnfSF         0.308159    0.214175   0.240257
# TotalBsmtSF       0.537808    0.434585   0.454868
# 1stFlrSF          0.476224    0.439317   0.566024
# 2ndFlrSF          0.295493    0.183926   0.687501
# LowQualFinSF     -0.030429   -0.094480   0.134683
# GrLivArea         0.593007    0.467247   1.000000
# BsmtFullBath      0.111098    0.131881   0.034836
# BsmtHalfBath     -0.040150   -0.020891  -0.018918
# FullBath          0.550600    0.469672   0.630012
# HalfBath          0.273458    0.219178   0.415772
# BedroomAbvGr      0.101676    0.086106   0.521270
# KitchenAbvGr     -0.183882   -0.050634   0.100063
# TotRmsAbvGrd      0.427452    0.362289   0.825489
# Fireplaces        0.396765    0.300789   0.461679
# GarageYrBlt       0.547766    0.588920   0.231197
# GarageCars        0.600671    1.000000   0.467247
# GarageArea        0.562022    0.882475   0.468997
# WoodDeckSF        0.238923    0.226342   0.247433
# OpenPorchSF       0.308819    0.213569   0.330224
# EnclosedPorch    -0.113937   -0.151434   0.009113
# 3SsnPorch         0.030371    0.035765   0.020643
# ScreenPorch       0.064886    0.050494   0.101510
# PoolArea          0.065166    0.020934   0.170205
# MiscVal          -0.031406   -0.043080  -0.002416
# MoSold            0.070815    0.040522   0.050240
# YrSold           -0.027347   -0.039117  -0.036526
# SalePrice         0.790982    0.640409   0.708624

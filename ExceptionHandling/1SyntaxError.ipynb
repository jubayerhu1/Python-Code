# %% [markdown]
# # Exception Handling in Python
# - There are 2 stages where error may happen in a program
#
#         - During compliation -> Syntax Error
#         - During execution -> Exceptions
#
# ## Syntax Error
#
# - Something in the program is not written according to the program grammar.
# - Error is raised by the interpreter / compiler
# - You can solve it by rectifying the program

# %%
# Examples of syntax erro
print 'Hello world'
# Out:
#   Cell In[1], line 2
#     print 'Hello world'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# - avobe code is sysntax error | Missing parentheses in call to 'print'. Did you mean print(...)?
# - it is grammatical error.

# %%
# Examples of syntax error
print("Hellow world ")

# %% [markdown]
# ## Other examples of syntax erro
#
# - Leaving sysmbols like colone, brackets
# - Misspelling a keyword
# - Incorrect indentation
# - empty if/else / loops/class

# %%
dep hello(): #  key word error | it is suppose to def hello(): | intendtion

    pass
# Out:
#   Cell In[2], line 1
#     dep hello():
#         ^
# SyntaxError: invalid syntax

# %%
if 1==1 :
# Out:
#   Cell In[3], line 1
#     if 1==1 :
#              ^
# SyntaxError: incomplete input

# %%
a =5 
if a ==3. # colone : error 
    print("hello")
# Out:
#   Cell In[4], line 2
#     if a ==3
#             ^
# SyntaxError: expected ':'

# %%
a =5 
iff a ==3: # invalied syntax
    print("hello")
# Out:
#   Cell In[5], line 2
#     iff a ==3:
#         ^
# SyntaxError: invalid syntax

# %%
# indented error 
a =5 
if a ==5:
print("hello ") # error of IndentationError:
# Out:
#   Cell In[6], line 4
#     print("hello ") # error of indented
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
# Index Error 
# The IndexError is thrown when trying to access an item at an invalid index

L = [1,2,3]
l[100] # index error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # Index Error
#       2 # The IndexError is thrown when trying to access an item at an invalid index
#       4 L = [1,2,3]
# ----> 5 l[100]
#
# NameError: name 'l' is not defined

# %%
# Module Not Found Error
# The ModuleNot Found Error is thrown when a module could not be found.

import maths
maths.floor(5.3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       1 # Module Not Found Error
#       2 # The ModuleNot Found Error is thrown when a module could not be found.
# ----> 4 import maths
#       5 maths.floor(5.3)
#
# ModuleNotFoundError: No module named 'maths'

# %%
# key error 
# The key error is thrown when a key is not found 
d = {'name': 'Jubayer'}
d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 4
#       1 # key error
#       2 # The key error is thrown when a key is not found
#       3 d = {'name': 'Jubayer'}
# ----> 4 d['age']
#
# KeyError: 'age'

# %%
# Type Error 
# The TypeError is thrown an operation or function is applied to an object of an 

1+'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 # Type Error
#       2 # The TypeError is thrown an operation or function is applied to an object of an
# ----> 4 1+'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# ValueError 
# The value Error is thrown when a function's argument is of an inappropriation

int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 # ValueError
#       2 # The value Error is thrown when a function's argument is of an inappropriation
# ----> 4 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# Name Error 
# The Name Error is thrown when an object could not be found.
print(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Name Error
#       2 # The Name Error is thrown when an object could not be found.
# ----> 3 print(k)
#
# NameError: name 'k' is not defined

# %%
# Attribute Error
l = [1,2,3]
l.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Attribute Error
#       2 l = [1,2,3]
# ----> 3 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# ### all these are syntax error | grammatically error

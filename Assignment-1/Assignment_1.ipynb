# %% [markdown]
# #Assignment

# %%
#Write a progrma that takes the current temperature as input and print.

tem=int(input('Enter the current temperature :'))

if tem <= 9:
    print( "It's too cold !")
elif 10 <= tem <=25:
    print("It's cold out side")
else:
    print("It's hot out side ")
# Out:
# It's hot out side

# %%
# Ask the user for their account blance and the amount they want to withdraw .
balance =float(input("Your account blance is :"))
amount = float(input('Enter the amount  :'))

if amount >balance:
    print('Insufficinet Blance ')
else:
    balance -= amount
    print('Transaction Successful ')
    print(f"Remain blance is :{balance}")
# Out:
# Transaction Successful
# Remain blance is :100.0

# %%
#Assignment 3: Student greage calculator :
#Problem marks (0 - 100) and print grade base on :
"""● 90–100 → A+
● 80–89 → A
● 70–79 → B
● 60–69 → C
● Below 60 → Fail"""
mark = int(input("Enter your number : "))

if 90<= mark <=100 :
    print('A+')
elif 80 <= mark <90:
    print("A")
elif 70 <= mark <80:
    print('B')
elif 60 <= mark < 70:
    print('C')
else:
    print('Fail')
# Out:
# Fail

# %% [markdown]
# Assignment 4: Bus Ticket Discout
# Problem : Ask the use for age and print ticket price:
# Below 5 -> Free
# 5 - 18 ->50% Discount
# 6 or above  ->30% Discount
# otheres -> Full Price

# %%
ticket=500
age = int(input("Enter your age : "))

if age <= 5:
    discount= 0
    print( " Free ")
   
elif age <= 18:
    discount = 50
    print("50% Discount ")
    
elif age >= 60 :
    discount =30
    print ( "30% Discount")
    
    discount = 100
    print("Full price")
    
tk_price = ticket*discount/100
print("Ticket price is : ",tk_price)
# Out:
# Full price
# Ticket price is :  500.0

# %% [markdown]
# Assignment 5 : Restaurant Bill with Discount
# Problem : Take total bill amount from the user:
# if the bill is above 1000 ->apply discount
# other wise -> No discount
#     print the the final bill abount.

# %%
bill= float(input('Enter your bill :'))

if bill >1000:
    discount= 10
    dis=bill*discount/100
    print(dis)
    finalbill = bill-dis
    print(finalbill)
else:
    print("NO discount")
    print ("Your bill is :",bill)
# Out:
# NO discount
# Your bill is : 500.0

# %% [markdown]
# Assignment 6 : Login Authentication
# Problem : Take a username and password input :
# if username == " admin" and password =12345 -> print "login Successful"
# else -> print "Invalid Credentials"

# %%
unsername =input("Enter your username :")
password =input('Enter your password :')

actul_username = "admin"
actul_password = "12345"

if unsername == actul_username and password == actul_password :
    print( " Login Successful ")
else:
    print("Invalid Credentials ")
# Out:
#  Login Successful

# %% [markdown]
# Assignment 7 : Traffic Light system
# problem : Ask the user to input a color (red, yello, or green)
#
# * 1- "Stop" for red
# * 2- "Ready to stop for yellow
# * 3- "Go" For green
# * 4- "Invalied color" otherwise

# %%
light = input( "Enter the color : ")

if light == "red":
    print( "Stop")
elif light == "yello":
    print("Ready to stop")
elif light == "green":
    print("GO")
else:
    print("Invalid color")
# Out:
# Invalid color

# %% [markdown]
# Assignment 8 Leap year checker:

# %% [markdown]
# # Assignment 9 : Job Eligibility Checker
# problem : input age and qualification :
#  * if age >= 18 and qualification is graduate - print "Eligible for Job"
#  * else -> Not Eligible

# %%
age =int(input("Enter your age :"))
qualification =input("Enter your qualification :")

if age >=18 and qualification == 'graduate':
    print("Your are Eligible for Job")
else:
    print("Your not Eligible for jobs")
# Out:
# Your not Eligible for jobs

# %% [markdown]
# #Assignment 10: Electricity Bill Calculator
# Problem:
# * Input number of units consumed and calculate bill:
# ● Up to 100 units → 5 BDT per unit
# ● 101–200 units → 7 BDT per unit
# ● Above 200 units → 10 BDT per unit
# Print total payable amount.

# %%
bill =float(input("Your bill is :"))

if bill <=100:
    f_bill=bill*5
    print('Total payable amount is : ',f_bill)
elif 100 < bill <200 :
    f_bill=bill*7
    print('Total payable amount is : ',f_bill)
else:
    bill>200
    f_bill=bill*10
    print('Total payable amount is : ',f_bill)
# Out:
# Total payable amount is :  2010.0

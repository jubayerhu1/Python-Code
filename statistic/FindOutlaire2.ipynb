# %%
# data set
d = [ 1,2,3,5,6,40,10,20,15,14,18,19,20,35,36,35]

# %%
import pandas as pd
import numpy as np
import statistics as st
import seaborn as sns

# %% [markdown]
# # IQR
# ## Sort the data
# ## Calculate Q1(25%), and Q3(75%)
# ## IQR (Q3 -Q1)
# ## Find the lower Fence (Q1 - 1.5(IQR))
# ## Find the Upper Fence (Q3 = 1.5(IQR))

# %%
d = sorted(d)
print(d)
# Out:
# [1, 2, 3, 5, 6, 10, 14, 15, 18, 19, 20, 20, 35, 35, 36, 40]

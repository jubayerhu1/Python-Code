# %%
import pandas as pd 
import numpy as np
import statistics as st
import seaborn as sns

# %%
data = [1,2,3,4,5,6,7]
np.mean(data)
# Out:
# np.float64(4.0)

# %%
st.median(data)
# Out:
# 4

# %%
d = [1,2,2,3,4,5]
np.mean(d)
# Out:
# np.float64(2.8333333333333335)

# %%
d = [1,2,2,3,4,5,100]
mean_v= np.mean(d)

resutl = np.round(mean_v,2) #print(f"{mean_val:.2f}")
print(resutl)
# Out:
# 16.71

# %%
d = [1,2,2,33,33,4,5,100,300]
mean = st.mean(d)
print(mean)
mode = st.mode(d)
print(mode)

sns.boxplot(d)
# Out:
# 53.333333333333336
# 2
# <Axes: >

# %%
d = [1,2,2,3,4,5]
v = st.variance(d)
print(v)
# Out:
# 2.1666666666666665

# %%
st.stdev(d)
# Out:
# 1.4719601443879744

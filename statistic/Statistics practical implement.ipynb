# %% [markdown]
# # Statistic Practical Implement

# %% [markdown]
# ## Measure of central Tendency
# 1. Mean
# 2. Median
# 3. Mode

# %%
# Find out mean 
ages = [ 23,24,32,45,12,43,67,45,32,56,32,420]

# %%
import numpy as np

np.mean(ages)
# Out:
# np.float64(69.25)

# %%
#Median
np.median(ages)
# Out:
# np.float64(37.5)

# %%
ages = [ 23,24,32,45,12,43,67,45,32,56,32]

# %%
#Median
np.median(ages)
# Out:
# np.float64(32.0)

# %%
# mode 
# np.mode(ages) numpy dost have mode function you have to use statistics lib

# %%
import statistics as st

# your can calcualte mean , median, mode 
print(st.mean(ages))
print(st.median(ages))
print(st.mode(ages))
# Out:
# 69.25
# 37.5
# 32

# %% [markdown]
# ## want to see outlair  to use by seabor | metlop

# %%
ages = [ -10,23,24,32,45,12,43,67,45,32,56,32,100]

# %%
import seaborn as sns
sns.boxplot(ages)
# Out:
# <Axes: >

# %%
ages = [ 23,24,32,45,12,43,67,45,32,56,32,420]

# %%
import seaborn as sns
sns.boxplot(ages)
# Out:
# <Axes: >

# %% [markdown]
# ### 5 Number Summary :
# 1. Minimum
# 2. First quantile (25%) Q1
# 3. Median Quantile (50%)Q2
# 4. Third Quantile (75%)Q3
# 5. Mazxmum
#
# Boxplot
#
# ages = [ 23,24,32,45,12,43,67,45,32,56,32,420]

# %%
### 5 Number 
q1,q3 = np.percentile(ages,[25,75])
print(q1, q3)
# Out:
# 30.0 47.75

# %%
q1
# Out:
# np.float64(30.0)

# %%
q3
# Out:
# np.float64(47.75)

# %% [markdown]
# IQR = q1 -q3
# Lower_fence = q1 - 15.*(IQR)
# higer_fence = q3+1.5(IQR)

# %%
IQR = q3 - q1
Lower_fence = q1 - 1.5*(IQR)
higer_fence = q3 + 1.5*(IQR)

print ("-----")

print( Lower_fence, higer_fence)
# Out:
# -----
# 3.375 74.375

# %% [markdown]
# ## Measur eof Dispersion
#
# 1. Variance
# 2. Standard Deviation
#
# data
# ages = [ 23,24,32,45,12,43,67,45,32,56,32,420]

# %%
ages = [ 23,24,32,45,12,43,67,45,32,56,32]

# %%
# Variance  for sample data 
st.variance(ages)
# Out:
# 248.85454545454544

# %%
# standar deviation  google _ std in statistics  for sample data 
st.stdev(ages)
# Out:
# 15.775124261144361

# %% [markdown]
# For population data

# %%
st.pvariance(ages) # for populatio on data
# Out:
# 226.23140495867767

# %%
# standar devation to make square 

import math 
math.sqrt(st.pvariance(ages))
# Out:
# 15.040990823701664

# %% [markdown]
# Histograms and PDF
# ### seaborn

# %%
ages = [ 23,24,32,45,12,43,67,45,32,56,32]
sns.histplot(ages)
# Out:
# <Axes: ylabel='Count'>

# %%
#ages = [ 23,24,32,45,12,43,67,45,32,56,32] kde = Kernel Density Estimate | PDF 
sns.histplot(ages, kde =True)
# Out:
# <Axes: ylabel='Count'>

# %%
ages = [ 23,24,32,45,12,43,67,45,32,56,32,120]

sns.histplot(ages, kde = True). # log normal distribution
# Out:
# <Axes: ylabel='Count'>

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df['sepal_length'], kde = True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df['sepal_width'],kde = True) # it is normal distibution
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df['petal_length'], kde = True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df['petal_width'], kde = True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
# convert normal distribution
# google - numpy .random.normal
# create a normal distribution data

s = np.random.normal(0.5,0.2,1000)
#print(s)

# %%
sns.histplot(s,kde= True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Other Distribution
# Log Normal Distribution , Power law Distribution

# %%
# np random log normal distribution 

mu, sigma = 3.,1. # mean and standar deviation
s = np.random.lognormal(mu, sigma, 1000)

# %%
s
# Out:
# array([ 43.853207  ,   9.62312239,  70.91190899,  29.07311265,
#         13.38187769,  22.38393775,   9.96748331,  23.62784938,
#          7.17838463,  80.79426698,   7.41040567,   9.11021442,
#         12.61631365,  83.58002563,  27.78469286,  27.85982515,
#         34.50744553,  16.72386635,  26.959632  ,  90.7181819 ,
#         16.11022621, 100.75959721,  12.27838583,  47.77684431,
#         42.9162097 ,   9.32179558,  25.57514805,   2.30682948,
#        132.36999743,   3.4738994 ,  29.43966136,   1.68286549,
#        130.52357222,   5.51348392,   5.12367037,  13.3487401 ,
#        186.4008455 ,  24.74947993,   1.72628913,   3.04066657,
#          4.9288148 ,  47.89164665,  15.97625265,  22.53974951,
#         17.97729033,  13.53619277,  28.23841505,   5.37226468,
#        134.35152164,  34.09188503,  11.1379022 ,  32.60994995,
#         45.04575669,  37.20881391,  31.84881845,   7.71232637,
#         22.67047829,  16.67549296,  24.40716415,  14.03304244,
# ...

# %%
sns.histplot(s, kde =True)
# Out:
# <Axes: ylabel='Count'>

# %%
# Log distributio to normal distribution 
sns.histplot(np.log(s), kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
# log to normal distribution 

sns.histplot(np.log(s), kde =True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(ages, kde =True)
# Out:
# <Axes: ylabel='Count'>

# %%
# convert to normal distribution | it is called data transformation techinque
sns.histplot(np.log(ages), kde =True)
# Out:
# <Axes: ylabel='Count'>

# %%
# Check data is normal distribution is not ?

# %%
! pip install scipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 8.7 MB/s  0:00:02 eta 0:00:010:00:01
# ...

# %%
! pip install scipy

# %%
#### Q -Q plot 
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

# %%
def plot_data(sample):
    plt:figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(sample, dist = 'norm' , plot =pylba)
    plt.show()

# %%
#### Q-Q plot
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
# create a normal distributed data
s = np.random.normal(0.5,0.2,1000)

# %%
plot_data(s)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['sepal_width']
plot_data(df['sepal_width'])

# %%
# correlatio one data connection to another data.

# %% [markdown]
# ### area, nroom, price ,owner_name
# price is the  - >tartet future / cloumns
# area, nroom  -> input feature /cloumns
#
# it is called supervise model

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# How to perfor corr from the google | corr value 0 to 1 . o mean no,
df.corr(numeric_only = True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# pariplot show graph: 

sns.pairplot(df)

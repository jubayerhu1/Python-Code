# %% [markdown]
# # Tuple

# %%
# This is string
t = ("Jubayer")
t1 = (type(t))
print(t1)
# Out:
# <class 'str'>

# %%
# This is tupe p
t = ("Jubayer",)
t1 = (type(t))
print(t1)
# Out:
# <class 'tuple'>

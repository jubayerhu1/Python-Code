# %% [markdown]
# # Assignment -2

# %% [markdown]
# ## 1
# '''1. Email Validator (String Filtering + Loops)
# 💼 Real-world use: Used in signup forms or data cleaning tasks.
# Task:
# Check if a given email is valid — must contain “@” and end with “.com” or “.org”.
# Example:
# Input: hello@inceptionbd.com
# Output: Valid Email'''

# %%
# 1
'''1. Email Validator (String Filtering + Loops)
💼 Real-world use: Used in signup forms or data cleaning tasks.
Task:
Check if a given email is valid — must contain “@” and end with “.com” or “.org”.
Example:
Input: hello@inceptionbd.com
Output: Valid Email'''

email = "hello@inceptionbd.com"

if (("@" in email) and (email.endswith(".com") or email.endswith(".org"))):
    print("Valid email")
else:
    print("Invalied email address")
# Out:
# Valid email

# %% [markdown]
# ## 2
# '''2. Count Word Frequency in Customer Reviews
# 💼 Real-world use: Analyzing reviews or comments in text analytics.
# Task:
# Given a review text, count how many times each word appears (ignore case).
# Example:
# Input: "This product is good and this service is excellent"
# Output: {'this': 2, 'product': 1, 'is': 2, 'good': 1, 'and': 1, 'service': 1, 'excellent': 1}'''

# %%
# 2
'''2. Count Word Frequency in Customer Reviews
💼 Real-world use: Analyzing reviews or comments in text analytics.
Task:
Given a review text, count how many times each word appears (ignore case).
Example:
Input: "This product is good and this service is excellent"
Output: {'this': 2, 'product': 1, 'is': 2, 'good': 1, 'and': 1, 'service': 1, 'excellent': 1}'''

input = "This product is good and this service is excellent".lower()

words = input.split()


words_count = {}
 
for word in words:
    if word in words_count:
        words_count[word] += 1
    else:
        words_count[word] = 1

print(words_count)
# Out:
# {'this': 2, 'product': 1, 'is': 2, 'good': 1, 'and': 1, 'service': 1, 'excellent': 1}

# %%
# 3 Password Strength checker 

input = "Hello@123"

# %%
# 4 Username Generator

# %% [markdown]
# ## 5
# '''5. SMS Word Counter
# 💼 Real-world use: Used in messaging apps or social media post limit check.
# Task:
# Count how many characters and words are in a message, and tell if it exceeds 160 characters (SMS limit).
# Example:
# Input: "This is a demo message."
# Output: Words = 5, Characters = 23, Status = Within Limit'''

# %%
# 5
'''5. SMS Word Counter
💼 Real-world use: Used in messaging apps or social media post limit check.
Task:
Count how many characters and words are in a message, and tell if it exceeds 160 characters (SMS limit).
Example:
Input: "This is a demo message."
Output: Words = 5, Characters = 23, Status = Within Limit'''

text = "This is a demo message."
characters = len(text)

text = text.split(" ")

word_count = len(text)

 
statues = characters > 160

if characters >160:
     status ='excced'
else:
     status = "within limit"



print(f"word = {word_count}, Character = {characters} , status = {status}")
# Out:
# word = 5, Character = 23 , status = within limit

# %% [markdown]
# ## 6
# """6. Remove Duplicates from Contact List
# 💼 Real-world use: Data cleaning in CRM or user databases.
# Task:
# Given a list of names (comma separated), remove duplicates.
# Example:
# Input: "Rahim, Karim, Rahim, Sultana"
# Output: "Rahim, Karim, Sultana" """

# %%
# 6
"""6. Remove Duplicates from Contact List
💼 Real-world use: Data cleaning in CRM or user databases.
Task:
Given a list of names (comma separated), remove duplicates.
Example:
Input: "Rahim, Karim, Rahim, Sultana"
Output: "Rahim, Karim, Sultana" """

input = "Rahim, Karim, Rahim, Sultana".split( " ")



unique_list = []


for name in input:
  if name not in unique_list:
    unique_list.append(name)
    
   
output = " ".join(unique_list)        
print(output)
# Out:
# Rahim, Karim, Sultana

# %%
# 7 Detect suspicious word in text (moderation)

# %% [markdown]
# ## 8
#
#
# '''8. Invoice Code Formatter
# 💼 Real-world use: Formatting IDs or codes in finance or ERP systems.
# Task:
# Given an invoice number like 23, generate code in the format INV00023.
# Example:
# Input: 23
# Output: INV00023 '''

# %%
# 8


'''8. Invoice Code Formatter
💼 Real-world use: Formatting IDs or codes in finance or ERP systems.
Task:
Given an invoice number like 23, generate code in the format INV00023.
Example:
Input: 23
Output: INV00023 '''

input = 23

output = f"INV{input:05d}" # pads leading zeros to 5 digit 
print(output)
# Out:
# INV00023

# %% [markdown]
# ## 9
# Count how many hashtags (#) and mentions (@) appear in a post.
# Example:
# Input: "Check out #AIWorkshop and follow @inceptionbd"
# Output: Hashtags = 1, Mentions = 1

# %%
'''9 . count Hashtaggs and Mentions ( social Media Analytics)
# Task : Count how many hashtags (#) and mentions (@) appear in a post.
Example:
Input: "Check out #AIWorkshop and follow @inceptionbd"
Output: Hashtags = 1, Mentions = 1 '''

text = "Check out #AIWorkshop and follow @inceptionbd"
hashtags = text.count("#")
mentions = text.count("@")
print(f"Hashtags = {hashtags}, Mention = {mentions}")
# Out:
# Hashtags = 1, Mention = 1

# %% [markdown]
# ## 10
# """10. Word Reversal for Data Encryption
# 💼 Real-world use: Simple text obfuscation or playful encoding.
# Task:
# Reverse each word in a sentence while keeping word order the same."""

# %%
# 10
"""10. Word Reversal for Data Encryption
💼 Real-world use: Simple text obfuscation or playful encoding.
Task:
Reverse each word in a sentence while keeping word order the same."""

input = "AI is fun"
reversed_words_list = []
words = input.split()



for wo in words:
    
    reverse_word = wo[::-1]
    
    reversed_words_list.append(reverse_word)


output =" ".join(reversed_words_list)
print(output)
# Out:
# IA si nuf

# %% [markdown]
# # Pandas Profiling Lib
# ## pip installyddata-profiling

# %%
pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (4.18.1)
# Requirement already satisfied: scipy<1.17,>=1.8 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (2.12.5)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (2.3.0)
# Requirement already satisfied: minify-html>=0.15.0 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.2 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from imagehash==4.3.2->ydata-profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.3)
# Requirement already satisfied: joblib>=0.14.1 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.11.12)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: attrs>=19.3.0 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/jub/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from ydata_profiling import ProfileReport

# %%
# list of data sets in sns 
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Titanic data set

ti = sns.load_dataset('titanic')

# %%
ti.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %% [markdown]
# # Profile Report

# %%
prof = ProfileReport(ti)
prof.to_file(output_file = 'Titanic.html')
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 24235.19it/s]0:00, 149.98it/s, Describe variable: alone]
# Summarize dataset: 100%|██████████| 41/41 [00:01<00:00, 37.12it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  9.69it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 385.65it/s]

# %% [markdown]
# # tips data profiling

# %%
tips = sns.load_dataset('tips')

# %%
prof = ProfileReport(tips)

prof.to_file(output_file = 'tips.html')
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 174762.67it/s]0:00, 166.30it/s, Describe variable: size]
# Summarize dataset: 100%|██████████| 25/25 [00:00<00:00, 61.06it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:00<00:00,  1.96it/s]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00, 25.97it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 578.68it/s]

# %% [markdown]
# EDA - Univaiate Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Volumes/study/A_data-science/Python-Code/EDA/.env/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Categorical Data 1st start when you analysis data
# count plot -> work how many sub categori have it .

sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
# New update  seaborn 0 = Death and 1 = live
sns.countplot(df, x = 'Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# Most location of Passenger columns name is = Embarked
'''Key details regarding the embarkation:
Southampton (S): The primary port of departure, where the majority of passengers and crew boarded.
Cherbourg (C): The second stop, known for boarding many first-class passengers.
Queenstown (Q): The final, third stop in Ireland before crossing the Atlantic.'''


sns.countplot(df, x = 'Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
# most class passenger - Pclass | 3rd class most passenger 
sns.countplot(df, x = 'Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# how many alive and death 0 = Death and live =1

df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Pic chart :
df['Survived'].value_counts().plot(kind = 'pie', autopct= '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Pic chart :
df['Embarked'].value_counts().plot(kind = 'pie', autopct= '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Pic chart :
df['Pclass'].value_counts().plot(kind = 'pie', autopct= '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Numberical Data 
# a. Histogram
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# a. Histogram for import matplotlib.pyplot as plt | need to create range 

plt.hist(df['Age'],bins = 5) # bin means bar size
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
# Seabor displot update inside of seaborn
sns.displot(df["Age"])

# %%
# Boxplot 
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('models/ohe_sex.pkl', 'rb'))
ohe_embarked = pickle.load(open('models/ohe_embarked.pkl', 'rb'))
clf = pickle.load(open('models/clf.pkl','rb'))

# %%
# ===============
# Assume user input 
# Pclass/gender/age/sibsp/Fare/Embarked

test_input = np.array([2,'male', 31.0, 0, 0, 10.5, 's'], dtype = object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 's']], dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# /opt/anaconda3/envs/jub/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
#test_input_embarked = ohe_embarked.transform(test_input[:, -1].reshape(1,1))

# %%
#test_input_embarked

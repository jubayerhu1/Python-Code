# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
# Assume user input 
test_input2 = np.array([2, 'male',31.0, 0, 0, 10.5, 's'], dtype = object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# /opt/anaconda3/envs/jub/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /opt/anaconda3/envs/jub/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# 2nd test from user 

test_input3 = np.array([4,'male',31.0, 0,0, 10.5, 's'], dtype = object).reshape(1,7)

# %%
pipe.predict(test_input3)
# Out:
# /opt/anaconda3/envs/jub/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /opt/anaconda3/envs/jub/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
